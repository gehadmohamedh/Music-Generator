# %%
from collections import defaultdict
import random
import os 
import pandas as pd

# %%
chords_file = "chordlab\The Beatles"
files = os.listdir(chords_file)

# %%
''''chords_file = "all chords"
chordsloc = os.listdir(chords_file)
index = 0 
for i in chordsloc :
    dataframe = open(chords_file+"\\"+i)
    dataframe1 = pd.DataFrame(dataframe1)
    dataframe1.to_csv('chordscsv\\'+str(index)+'.csv', 
                  index = None)
    index+=1'''

# %%
index = 0
chords = []
for i in chordsloc :
    df = pd.read_csv("chordscsv\\"+str(index)+'.csv')
    for i in df['0']:
        chords.append(i.split(' ')[2].replace('\n', ''))
    index+=1
chords.append("#END#")
print(chords)
# Out:
# ['N', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G', 'B:min7', 'A:min7', 'D:sus4', 'D', 'G', 'B:min7', 'A:min7', 'C/5', 'B:min', 'A:min', 'C/5', 'D/3', 'G', 'B:min7', 'A:min7', 'B:min', 'A:min', 'C', 'D', 'G:maj7', 'C:maj(#4)/5', 'G:maj7', 'C:maj(#4)/5', 'G', 'C/5', 'G', 'C/5', 'G', 'B:min7', 'A:min7', 'C/5', 'B:min', 'A:min', 'C/5', 'D/3', 'G', 'B:min7', 'A:min7', 'B:min', 'A:min', 'C/5', 'D/3', 'G:maj7', 'C:maj(#4)/5', 'G:maj7', 'C:maj(#4)/5', 'G', 'C/5', 'G', 'C/5', 'G', 'A:min', 'A', 'D:min', 'G', 'C/5', 'D/3', 'C', 'D', 'G', 'B:min7', 'A:min7', 'C/5', 'B:min', 'A:min', 'C/5', 'D/3', 'G', 'B:min7', 'A:min7', 'B:min', 'A:min', 'C/5', 'D/3', 'G:maj7', 'C:maj(#4)/5', 'G:maj7', 'C:maj(#4)/5', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G', 'B:min7', 'A:min7', 'C/5', 'G', 'B:min7', 'A:min7', 'D:sus4', 'D', 'G', 'N', 'N', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G', 'B:min7', 'A:min7', 'D:sus4', 'D', 'G', 'B:min7', 'A:min7', 'C/5', 'B:min', 'A:min', 'C/5', 'D/3', 'G', 'B:min7', 'A:min7', 'B:min', 'A:min', 'C', 'D', 'G:maj7', 'C:maj(#4)/5', 'G:maj7', 'C:maj(#4)/5', 'G', 'C/5', 'G', 'C/5', 'G', 'B:min7', 'A:min7', 'C/5', 'B:min', 'A:min', 'C/5', 'D/3', 'G', 'B:min7', 'A:min7', 'B:min', 'A:min', 'C/5', 'D/3', 'G:maj7', 'C:maj(#4)/5', 'G:maj7', 'C:maj(#4)/5', 'G', 'C/5', 'G', 'C/5', 'G', 'A:min', 'A', 'D:min', 'G', 'C/5', 'D/3', 'C', 'D', 'G', 'B:min7', 'A:min7', 'C/5', 'B:min', 'A:min', 'C/5', 'D/3', 'G', 'B:min7', 'A:min7', 'B:min', 'A:min', 'C/5', 'D/3', 'G:maj7', 'C:maj(#4)/5', 'G:maj7', 'C:maj(#4)/5', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G', 'B:min7', 'A:min7', 'C/5', 'G', 'B:min7', 'A:min7', 'D:sus4', 'D', 'G', 'N', 'N', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G', 'B:min7', 'A:min7', 'D:sus4', 'D', 'G', 'B:min7', 'A:min7', 'C/5', 'B:min', 'A:min', 'C/5', 'D/3', 'G', 'B:min7', 'A:min7', 'B:min', 'A:min', 'C', 'D', 'G:maj7', 'C:maj(#4)/5', 'G:maj7', 'C:maj(#4)/5', 'G', 'C/5', 'G', 'C/5', 'G', 'B:min7', 'A:min7', 'C/5', 'B:min', 'A:min', 'C/5', 'D/3', 'G', 'B:min7', 'A:min7', 'B:min', 'A:min', 'C/5', 'D/3', 'G:maj7', 'C:maj(#4)/5', 'G:maj7', 'C:maj(#4)/5', 'G', 'C/5', 'G', 'C/5', 'G', 'A:min', 'A', 'D:min', 'G', 'C/5', 'D/3', 'C', 'D', 'G', 'B:min7', 'A:min7', 'C/5', 'B:min', 'A:min', 'C/5', 'D/3', 'G', 'B:min7', 'A:min7', 'B:min', 'A:min', 'C/5', 'D/3', 'G:maj7', 'C:maj(#4)/5', 'G:maj7', 'C:maj(#4)/5', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G', 'B:min7', 'A:min7', 'C/5', 'G', 'B:min7', 'A:min7', 'D:sus4', 'D', 'G', 'N', 'N', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G', 'B:min7', 'A:min7', 'D:sus4', 'D', 'G', 'B:min7', 'A:min7', 'C/5', 'B:min', 'A:min', 'C/5', 'D/3', 'G', 'B:min7', 'A:min7', 'B:min', 'A:min', 'C', 'D', 'G:maj7', 'C:maj(#4)/5', 'G:maj7', 'C:maj(#4)/5', 'G', 'C/5', 'G', 'C/5', 'G', 'B:min7', 'A:min7', 'C/5', 'B:min', 'A:min', 'C/5', 'D/3', 'G', 'B:min7', 'A:min7', 'B:min', 'A:min', 'C/5', 'D/3', 'G:maj7', 'C:maj(#4)/5', 'G:maj7', 'C:maj(#4)/5', 'G', 'C/5', 'G', 'C/5', 'G', 'A:min', 'A', 'D:min', 'G', 'C/5', 'D/3', 'C', 'D', 'G', 'B:min7', 'A:min7', 'C/5', 'B:min', 'A:min', 'C/5', 'D/3', 'G', 'B:min7', 'A:min7', 'B:min', 'A:min', 'C/5', 'D/3', 'G:maj7', 'C:maj(#4)/5', 'G:maj7', 'C:maj(#4)/5', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G', 'B:min7', 'A:min7', 'C/5', 'G', 'B:min7', 'A:min7', 'D:sus4', 'D', 'G', 'N', 'N', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G', 'B:min7', 'A:min7', 'D:sus4', 'D', 'G', 'B:min7', 'A:min7', 'C/5', 'B:min', 'A:min', 'C/5', 'D/3', 'G', 'B:min7', 'A:min7', 'B:min', 'A:min', 'C', 'D', 'G:maj7', 'C:maj(#4)/5', 'G:maj7', 'C:maj(#4)/5', 'G', 'C/5', 'G', 'C/5', 'G', 'B:min7', 'A:min7', 'C/5', 'B:min', 'A:min', 'C/5', 'D/3', 'G', 'B:min7', 'A:min7', 'B:min', 'A:min', 'C/5', 'D/3', 'G:maj7', 'C:maj(#4)/5', 'G:maj7', 'C:maj(#4)/5', 'G', 'C/5', 'G', 'C/5', 'G', 'A:min', 'A', 'D:min', 'G', 'C/5', 'D/3', 'C', 'D', 'G', 'B:min7', 'A:min7', 'C/5', 'B:min', 'A:min', 'C/5', 'D/3', 'G', 'B ...

# %%
'''chords_file = "chords"
chordsloc = os.listdir(chords_file)
for i in chordsloc :
    with open(chords_file+"/"+i, 'r') as f:
        chords = [x.replace('\n', '') for x in f.readlines()]
    chords.append("#END#")
    print(chords)'''
# Out:
# 'chords_file = "chords"\nchordsloc = os.listdir(chords_file)\nfor i in chordsloc :\n    with open(chords_file+"/"+i, \'r\') as f:\n        chords = [x.replace(\'\n\', \'\') for x in f.readlines()]\n    chords.append("#END#")\n    print(chords)'

# %%
def calculate_probabilities(tokens, ngrams=2):
    probs = dict()
    for i in range(ngrams, len(tokens)-1):
        if tuple(tokens[i-ngrams:i]) not in probs:
            probs[tuple(tokens[i-ngrams:i])] = dict()
        
        if tokens[i] not in probs[tuple(tokens[i-ngrams:i])]:
            probs[tuple(tokens[i-ngrams:i])][tokens[i]] = 0
        probs[tuple(tokens[i-ngrams:i])][tokens[i]] += 1
    
    for node in probs:
        total = sum(probs[node].values()) + len(probs[node].values())
        for next_token in probs[node]:
            probs[node][next_token] = (probs[node][next_token] + 1) / total
        
    return probs

# %%
probs = calculate_probabilities(chords)

# %%
probs
# Out:
# {('N', 'G:maj7'): {'C/5': 1.0},
#  ('G:maj7', 'C/5'): {'G:maj7': 0.666358595194085, 'G': 0.333641404805915},
#  ('C/5', 'G:maj7'): {'C/5': 1.0},
#  ('C/5', 'G'): {'B:min7': 0.5708630245447348,
#   'C/5': 0.28582739509105304,
#   'A:min': 0.14330958036421218},
#  ('G', 'B:min7'): {'A:min7': 1.0},
#  ('B:min7', 'A:min7'): {'D:sus4': 0.2224276032039433,
#   'C/5': 0.44423906346272335,
#   'B:min': 0.3333333333333333},
#  ('A:min7', 'D:sus4'): {'D': 1.0},
#  ('D:sus4', 'D'): {'G': 1.0},
#  ('D', 'G'): {'B:min7': 0.6660516605166051, 'N': 0.3339483394833948},
#  ('A:min7', 'C/5'): {'B:min': 0.7493074792243767, 'G': 0.25069252077562326},
#  ('C/5', 'B:min'): {'A:min': 1.0},
#  ('B:min', 'A:min'): {'C/5': 0.83271719038817, 'C': 0.16728280961182995},
#  ('A:min', 'C/5'): {'D/3': 1.0},
#  ('C/5', 'D/3'): {'G': 0.4995383194829178,
#   'G:maj7': 0.3333333333333333,
#   'C': 0.16712834718374883},
#  ('D/3', 'G'): {'B:min7': 1.0},
#  ('A:min7', 'B:min'): {'A:min': 1.0},
#  ('A:min', 'C'): {'D': 1.0},
#  ('C', 'D'): {'G:maj7': 0.5, 'G': 0.5},
#  ('D', 'G:maj7'): {'C:maj(#4)/5': 1.0},
#  ('G:maj7', 'C:maj(#4)/5'): {'G:maj7': 0.666358595194085,
#   'G': 0.333641404805915},
#  ('C:maj(#4)/5', 'G:maj7'): {'C:maj(#4)/5': 0.7493074792243767,
#   'C/5': 0.25069252077562326},
#  ('C:maj(#4)/5', 'G'): {'C/5': 1.0},
#  ('G', 'C/5'): {'G': 0.7993348115299335, 'D/3': 0.2006651884700665},
#  ('D/3', 'G:maj7'): {'C:maj(#4)/5': 1.0},
#  ('G', 'A:min'): {'A': 1.0},
#  ('A:min', 'A'): {'D:min': 1.0},
#  ('A', 'D:min'): {'G': 1.0},
#  ('D:min', 'G'): {'C/5': 1.0},
#  ('D/3', 'C'): {'D': 1.0},
#  ('G', 'N'): {'N': 1.0},
#  ('N', 'N'): {'G:maj7': 1.0}}

# %%
def random_walk(probs, ngrams=2, starting_chords=('F', 'G7'), chord_count=10):
    chords = list(starting_chords)
    for i in range(ngrams-1, chord_count):
        current = tuple(chords[i-ngrams+1:i+1])
        chords += random.choices(list(probs[current].keys()),
                                 list(probs[current].values()))
    return chords

# %%
print(random_walk(probs, starting_chords=('G', 'N'), chord_count=30))
# Out:
# ['G', 'N', 'N', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G:maj7', 'C/5', 'G', 'C/5', 'G', 'B:min7', 'A:min7', 'C/5', 'G', 'B:min7', 'A:min7', 'B:min', 'A:min', 'C/5', 'D/3', 'G:maj7', 'C:maj(#4)/5', 'G', 'C/5', 'G', 'B:min7', 'A:min7', 'C/5', 'B:min']
